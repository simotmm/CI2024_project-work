# %% [markdown]
# # Symbolic Regression, Genetic Programming

# %% [markdown]
# ### Imports
# - Warning are filtered because they are correctly treated during the program.
# - Settings class to set parameters.
# - Utils functions to get data and find solutions.

# %%
import warnings #per evitare molti warning durante la generazione degli individui
warnings.filterwarnings('ignore', category=RuntimeWarning)
from classes import Settings
from utils import get_problems, set_problems_settings, get_solutions, python_file_output

# %% [markdown]
# ### Problems data and settings

# %%
problems = get_problems()

SETTINGS = [
    #p0 settings --> not used
    Settings(0, 0, 0, 0.0, 0.0),

    #p1 settings --> ok
    Settings(20, 30, 4, 0.4, 0.7),

    #p2 settings -->
    Settings(20, 40, 4, 0.4, 0.7),

    #p3 settings -->
    Settings(20, 40, 4, 0.4, 0.7),

    #p4 settings --> 
    Settings(100, 140, 8, 0.4, 0.7),

    #p5 settings --> ok
    Settings(20, 30, 4, 0.4, 0.7),

    #p6 settings --> quasi ok
    Settings(50, 100, 10, 0.5, 0.7),

    #p7 settings -->
    Settings(20, 40, 4, 0.4, 0.7),

    #p8 settings -->
    Settings(20, 40, 4, 0.4, 0.7)
]

PROBLEMS = [
    problems[1],
    problems[2],
    problems[3],
    problems[4],
    problems[5],
    problems[6],
    problems[7],
    problems[8]
]

PROBLEM = 4
#PROBLEMS = [PROBLEMS[PROBLEM-1]]
set_problems_settings(PROBLEMS, SETTINGS)

# %% [markdown]
# ### Solutions provided by genetic programming algorithm

# %%
solutions = get_solutions(PROBLEMS)
# Out:
# problem 1:
# x.shape: (1, 500)
# pop_dim: 20, max_gen: 30, depth: 4, mut: 40.0%, crossover: 70.0%
# algorithm: adaptive
# [##################################################] 100.00%
# final mut: 40.0%, final crossover: 69.0%
# f(x) = np.sin(x[0])
# fitness value: 1.0
# mean square error: 7.125940794232773e-34
#
# problem 2:
# x.shape: (3, 5000)
# pop_dim: 20, max_gen: 40, depth: 4, mut: 40.0%, crossover: 70.0%
# algorithm: adaptive
# [##################################################] 100.00%
# final mut: 46.00000000000001%, final crossover: 59.999999999999986%
# f(x) = ((0.91 / (0.17 ** x[0])) * (0.17 / (0.17 ** x[0])))
# fitness value: -28863058978930.965
# mean square error: 28863058978930.99
#
# problem 3:
# x.shape: (3, 5000)
# pop_dim: 20, max_gen: 40, depth: 4, mut: 40.0%, crossover: 70.0%
# algorithm: adaptive
# [##################################################] 100.00%
# final mut: 52.000000000000014%, final crossover: 54.999999999999986%
# ...

# %% [markdown]
# ### Util output function
# To eventually update the `s333017.py` file.

# %%
python_file_output(solutions)
# Out:
# #python code s333017.py
# import numpy as np
#
# #problem 1:
# #mean square error: 7.125940794232773e-34
# def f1(x: np.ndarray) -> np.ndarray:
#     return np.sin(x[0])
#
# #problem 2:
# #mean square error: 28863058978930.99
# def f2(x: np.ndarray) -> np.ndarray:
#     return ((0.91 / (0.17 ** x[0])) * (0.17 / (0.17 ** x[0])))
#
# #problem 3:
# #mean square error: 215.54095908246478
# def f3(x: np.ndarray) -> np.ndarray:
#     return ((np.cosh(x[0]) - np.sinh(x[1])) - np.sinh(x[1]))
#
# #problem 4:
# #mean square error: 3.567505634584438
# def f4(x: np.ndarray) -> np.ndarray:
#     return ((np.cos(x[1]) // 0.24) + (0.84 / 0.27))
#
# #problem 5:
# #mean square error: 5.572810232617333e-18
# def f5(x: np.ndarray) -> np.ndarray:
#     return 0.00
#
# #problem 6:
# #mean square error: 0.0182721257356195
# def f6(x: np.ndarray) -> np.ndarray:
#     return ((x[1] / np.tanh(0.71)) - (x[0] * 0.71))
#
# #problem 7:
# #mean square error: 680.2675568491251
# ...
